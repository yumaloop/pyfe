# %%
import numpy as np
import yfinance as yf

from IPython.display import display, Markdown
from pprint import pprint

# %%
# トヨタ自動車
ticker = yf.Ticker("7203.T")

# %%
# 価格データ
hist = ticker.history(period="max")
print(hist)
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 1999-05-06  2296.554421  2375.519043  2270.232880  2375.519043   3115000
# 1999-05-07  2362.359368  2368.939756  2270.233933  2289.975098   3033000
# 1999-05-10  2289.974429  2316.295974  2270.233270  2283.394043   1261000
# 1999-05-11  2303.135646  2316.296421  2263.653320  2263.653320   1686000
# 1999-05-12  2263.652215  2303.134521  2263.652215  2303.134521   2596000
# ...                 ...          ...          ...          ...       ...
# 2020-11-06  7070.000000  7152.000000  7015.000000  7019.000000  11092900
# 2020-11-09  7159.000000  7242.000000  7119.000000  7173.000000   7838600
# 2020-11-10  7320.000000  7360.000000  7212.000000  7267.000000   8825700
# 2020-11-11  7390.000000  7503.000000  7369.000000  7503.000000  10075300
# 2020-11-12  7477.000000  7507.000000  7380.000000  7435.000000   5816400
#
#             Dividends  Stock Splits
# Date
# 1999-05-06        0.0             0
# 1999-05-07        0.0             0
# 1999-05-10        0.0             0
# 1999-05-11        0.0             0
# 1999-05-12        0.0             0
# ...               ...           ...
# 2020-11-06        0.0             0
# 2020-11-09        0.0             0
# 2020-11-10        0.0             0
# 2020-11-11        0.0             0
# 2020-11-12        0.0             0
#
# [5327 rows x 7 columns]

# %%
from IPython.display import display, Markdown
title = "hoge"
url = "foo"
Markdown('<strong>{}</strong><br/>{}'.format(title, url))
# Out:
# <strong>hoge</strong><br/>foo

# %% [markdown]
# ### 財務諸表

# %%
# 損益計算書
financials = ticker.financials
print("\n損益計算書\n")
display(financials)

# 貸借対照表
balance_sheet = ticker.balance_sheet
print("\n貸借対照表\n")
display(balance_sheet)

# キャッシュフロー計算書
cashflow = ticker.cashflow
print("\nキャッシュフロー計算書\n")
display(cashflow)
# Out:
# 損益計算書
#                                          2020-03-31   2019-03-31   2018-03-31  \
# Research Development                           None         None         None
# Effect Of Accounting Charges                   None         None         None
# Income Before Tax                       2.82576e+12  2.64553e+12  3.09051e+12
# Minority Interest                       6.77064e+11  7.18985e+11   6.9412e+11
# Net Income                              2.07618e+12  1.88287e+12  2.49398e+12
# Selling General Administrative          2.97317e+12   2.9867e+12   3.0905e+12
# Gross Profit                            5.40763e+12   5.4439e+12  5.49036e+12
# Ebit                                    2.43446e+12   2.4572e+12  2.39986e+12
# Operating Income                        2.43446e+12   2.4572e+12  2.39986e+12
# Other Operating Expenses                       None         None         None
# Interest Expense                        -3.2217e+10  -2.8078e+10  -2.7586e+10
# Extraordinary Items                            None         None         None
# Non Recurring                                  None         None         None
# Other Items                                    None         None         None
# Income Tax Expense                       6.8343e+11  6.59944e+11  5.04406e+11
# Total Revenue                             2.993e+13  3.02257e+13  2.93795e+13
# Total Operating Expenses                2.74955e+13  2.77685e+13  2.69796e+13
# Cost Of Revenue                         2.45224e+13  2.47818e+13  2.38892e+13
# Total Other Income Expense Net          3.91297e+11   1.8833e+11   6.9065e+11
# Discontinued Operations                        None         None         None
# Net Income From Continuing Ops          2.14233e+12  1.98559e+12  2.58611e+12
# Net Income Applicable To Common Shares   2.0589e+12  1.86808e+12  2.48169e+12
#
#                                          2017-03-31
# Research Development                           None
# Effect Of Accounting Charges                   None
# Income Before Tax                       2.55588e+12
# Minority Interest                       6.68264e+11
# Net Income                              1.83111e+12
# Selling General Administrative          2.86848e+12
# Gross Profit                            4.86286e+12
# Ebit                                    1.99437e+12
# Operating Income                        1.99437e+12
# Other Operating Expenses                       None
# Interest Expense                        -2.9353e+10
# Extraordinary Items                            None
# Non Recurring                                  None
# Other Items                                    None
# Income Tax Expense                        6.289e+11
# Total Revenue                           2.75972e+13
# Total Operating Expenses                2.56028e+13
# Cost Of Revenue                         2.27343e+13
# Total Other Income Expense Net          5.61513e+11
# Discontinued Operations                        None
# Net Income From Continuing Ops          1.92698e+12
# Net Income Applicable To Common Shares  1.82131e+12
# 貸借対照表
#                                     2020-03-31    2019-03-31    2018-03-31  \
# Capital Surplus                   4.893340e+11  4.871620e+11  4.875020e+11
# Total Liab                        3.194275e+13  3.186981e+13  3.087815e+13
# Total Stockholder Equity          2.006062e+13  1.934815e+13  1.873598e+13
# Minority Interest                 6.770640e+11  7.189850e+11  6.941200e+11
# Other Current Liab                4.102642e+12  4.479344e+12  4.399669e+12
# Total Assets                      5.268044e+13  5.193695e+13  5.030825e+13
# Common Stock                      3.970500e+11  3.970500e+11  3.970500e+11
# Other Current Assets              2.469880e+11  1.425310e+11  2.022920e+11
# Retained Earnings                 2.342761e+13  2.198752e+13  1.947346e+13
# Other Liab                        2.746823e+12  2.887743e+12  2.902003e+12
# Treasury Stock                   -4.253379e+12 -3.523575e+12 -1.622034e+12
# Other Assets                      8.905140e+11  1.182809e+12  1.067759e+12
# Cash                              2.774498e+12  2.790212e+12  2.390524e+12
# Total Current Liabilities         1.790238e+13  1.822694e+13  1.779689e+13
# Deferred Long Term Asset Charges  3.547850e+11  5.018720e+11  4.941200e+11
# Short Long Term Debt              1.418710e+11  1.560380e+11  1.674550e+11
# Other Stockholder Equity         -1.166273e+12 -9.166500e+11  4.356990e+11
# Property Plant Equipment          1.087864e+13  1.068549e+13  1.026767e+13
# Total Current Assets              1.864253e+13  1.887924e+13  1.815266e+13
# Long Term Investments             1.184489e+13  1.090829e+13  1.133854e+13
# Net Tangible Assets               2.006062e+13  1.934815e+13  1.873598e+13
# Short Term Investments            1.477202e+12  2.234892e+12  2.447703e+12
# Net Receivables                   2.659748e+12  2.940890e+12  2.708900e+12
# Long Term Debt                    1.029678e+12  7.655860e+11  5.910860e+11
# Inventory                         2.434918e+12  2.656396e+12  2.539789e+12
# Accounts Payable                  2.434180e+12  2.645984e+12  2.586657e+12
#
#                                     2017-03-31
# Capital Surplus                   4.840130e+11
# Total Liab                        3.056711e+13
# Total Stockholder Equity          1.751481e+13
# Minority Interest                 6.682640e+11
# Other Current Liab                3.979935e+12
# Total Assets                      4.875019e+13
# Common Stock                      3.970500e+11
# Other Current Assets              1.235700e+10
# Retained Earnings                 1.760107e+13
# Other Liab                        3.163780e+12
# Treasury Stock                   -9.673210e+11
# Other Assets                      1.012639e+12
# Cash                              2.257064e+12
# Total Current Liabilities         1.731896e+13
# Deferred Long Term Asset Charges  5.039850e+11
# Short Long Term Debt              2.285990e+11
# Other Stockholder Equity          6.409220e+11
# Property Plant Equipment          1.019711e+13
# Total Current Assets              1.783370e+13
# Long Term Investments             1.069452e+13
# Net Tangible Assets               1.751481e+13
# Short Term Investments            2.522598e+12
# Net Receivables                   2.552805e+12
# Long Term Debt                    5.784750e+11
# Inventory                         2.388617e+12
# Accounts Payable                  2.566382e+12
# キャッシュフロー計算書
#                                              2020-03-31    2019-03-31  \
# Investments                                2.334300e+11  6.166420e+11
# Change To Liabilities                     -7.641000e+10  9.488700e+10
# Total Cashflows From Investing Activities -3.150861e+12 -2.697241e+12
# Net Borrowings                             1.558199e+12  7.229710e+11
# Total Cash From Financing Activities       3.971380e+11 -5.408390e+11
# Change To Operating Activities            -2.703900e+11  4.084000e+11
# Net Income                                 2.076183e+12  1.882873e+12
# Change In Cash                             7.056750e+11  4.868760e+11
# Repurchase Of Stock                       -4.761290e+11 -5.496370e+11
# Effect Of Exchange Rate                   -1.312450e+11 -4.164100e+10
# Total Cash From Operating Activities       3.590643e+12  3.766597e+12
# Depreciation                               1.605383e+12  1.792375e+12
# Dividends Paid                            -6.299870e+11 -6.448060e+11
# Change To Inventory                       -1.140960e+11 -1.669020e+11
# Change To Account Receivables              2.488950e+11 -2.468450e+11
# Other Cashflows From Financing Activities -5.494500e+10 -6.936700e+10
# Change To Netincome                        2.228170e+11  1.431380e+11
# Capital Expenditures                      -3.595131e+12 -3.738887e+12
#
#                                              2018-03-31    2017-03-31
# Investments                               -3.322730e+11  6.950000e+08
# Change To Liabilities                      4.664800e+10  1.459570e+11
# Total Cashflows From Investing Activities -3.660092e+12 -2.969939e+12
# Net Borrowings                             6.893390e+11  1.030929e+12
# Total Cash From Financing Activities      -4.491350e+11 -3.751650e+11
# Change To Operating Activities             4.857250e+11  7.724320e+11
# Net Income                                 2.493983e+12  1.831109e+12
# Change In Cash                             7.031300e+10  2.098980e+11
# Repurchase Of Stock                       -4.478180e+11 -7.039860e+11
# Effect Of Exchange Rate                   -4.358800e+10 -1.348600e+10
# Total Cash From Operating Activities       4.223128e+12  3.568488e+12
# Depreciation                               1.734033e+12  1.610950e+12
# Dividends Paid                            -6.268920e+11 -6.381720e+11
# Change To Inventory                       -1.711480e+11 -2.463260e+11
# Change To Account Receivables             -1.054350e+11 -2.647840e+11
# Other Cashflows From Financing Activities -6.376400e+10 -6.393600e+10
# Change To Netincome                       -4.994310e+11 -1.598180e+11
# Capital Expenditures                      -3.598707e+12 -3.541437e+12

# %% [markdown]
# marketCap(時価総額)
# sharesOutstanding(発行株数)
# forwardPE(予測PER)
# dividendYield(配当利回り)
# profitMargins(純利益比率)

# %%
# 銘柄サマリ
info = ticker.info
pprint(info)
# Out:
# {'52WeekChange': -0.03745991,
#  'SandP52WeekChange': 0.15372515,
#  'address1': '1 Toyota-cho',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 7436,
#  'askSize': 0,
#  'averageDailyVolume10Day': 7925028,
#  'averageVolume': 4370307,
#  'averageVolume10days': 7925028,
#  'beta': 0.779987,
#  'beta3Year': None,
#  'bid': 7423,
#  'bidSize': 0,
#  'bookValue': 7514.668,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Toyota',
#  'companyOfficers': [],
#  'country': 'Japan',
#  'currency': 'JPY',
#  'dateShortInterest': None,
#  'dayHigh': 7507,
#  'dayLow': 7380,
#  'dividendRate': 220,
#  'dividendYield': 0.030299999,
#  'earningsQuarterlyGrowth': -0.205,
#  'enterpriseToEbitda': 11.515,
#  'enterpriseToRevenue': 1.408,
#  'enterpriseValue': 36640441499648,
#  'exDividendDate': 1601337600,
#  'exchange': 'JPX',
#  'exchangeTimezoneName': 'Asia/Tokyo',
#  'exchangeTimezoneShortName': 'JST',
#  'expireDate': None,
#  'fiftyDayAverage': 6994.8286,
#  'fiftyTwoWeekHigh': 8026,
#  'fiftyTwoWeekLow': 5771,
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': 3.25,
#  'floatShares': 2129778645,
#  'forwardEps': 836.47,
#  'forwardPE': 8.888544,
#  'fromCurrency': None,
#  'fullTimeEmployees': 359542,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '32400000',
#  'heldPercentInsiders': 0.23608999,
#  'heldPercentInstitutions': 0.22542,
#  'industry': 'Auto Manufacturers',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendDate': 1585526400,
#  'lastDividendValue': 120,
#  'lastFiscalYearEnd': 1585612800,
#  'lastMarket': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/global.toyota',
#  'longBusinessSummary': 'Toyota Motor Corporation designs, manufactures, '
#                         'assembles, and sells passenger vehicles, minivans and '
#                         'commercial vehicles, and related parts and '
#                         'accessories. It operates in Automotive, Financial '
#                         'Services, and All Other segments. The company offers '
#                         'hybrid cars under the Prius, Prius PHV, C-HR, LC HV, '
#                         'LS HV, Camry, JPN TAXI, Avalon, Crown, Century HV, UX '
#                         'HV, Corolla SD, Corolla Sport, and WG HV names; fuel '
#                         'cell vehicles under the MIRAI and SORA names; and '
#                         'conventional engine vehicles, including subcompact '
#                         'and compact cars under the Yaris, Aqua, Passo, Roomy, '
#                         'Tank, Etios, Vios, AGYA, Rush, GLANZA, and Raize '
#                         'names. It also provides mini-vehicles, passenger '
#                         'vehicles, commercial vehicles, and auto parts under '
#                         'the Toyota name; mid-size cars under the Camry and '
#                         'REIZ names; luxury cars under the Lexus, Avalon, and '
#                         'Crown names; Century limousines; sports cars under '
#                         'the LC and Supra names; and recreational and '
#                         'sport-utility vehicles under the Sequoia, 4Runner, '
#                         'RAV4, Highlander, and Land Cruiser names. In '
#                         'addition, the company offers pickup trucks under the '
#                         'Tacoma and Tundra names; Minivans, Cabwagons, and '
#                         'Semi-Bonnet Wagon under the Alphard, Vellfire, '
#                         'Noah/Voxy, Esquire, Calya, Estima, Sienta, and Sienna '
#                         'names; and trucks and buses. Further, it provides '
#                         'financial services, such as retail financing and '
#                         'leasing, wholesale financing, insurance, and credit '
#                         'cards; and designs, manufactures, and sells '
#                         'prefabricated housing. Additionally, the company '
#                         'operates GAZOO.com, a web portal for automobile '
#                         'information. It operates in Japan, North America, '
#                         'Europe, Asia, Central and South America, Oceania, '
#                         'Africa, and the Middle East. The company was founded '
#                         'in 1933 and is headquartered in Toyota, Japan.',
#  'longName': 'Toyota Motor Corporation',
#  'market': 'jp_market',
#  'marketCap': 20787962576896,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_319676',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1601424000,
#  'navPrice': None,
#  'netIncomeToCommon': 1421933019136,
#  'nextFiscalYearEnd': 1648684800,
#  'open': 7477,
#  'openInterest': None,
#  'payoutRatio': 0.4001,
#  'pegRatio': None,
#  'phone': '81 565 28 2121',
#  'previousClose': 7503,
#  'priceHint': 2,
#  'priceToBook': 0.98939836,
#  'priceToSalesTrailing12Months': 0.7989341,
#  'profitMargins': 0.054980002,
#  'quoteType': 'EQUITY',
#  'regularMarketDayHigh': 7507,
#  'regularMarketDayLow': 7380,
#  'regularMarketOpen': 7477,
#  'regularMarketPreviousClose': 7503,
#  'regularMarketPrice': 7477,
#  'regularMarketVolume': 5816400,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Consumer Cyclical',
#  'sharesOutstanding': 2795960064,
#  'sharesPercentSharesOut': None,
#  'sharesShort': None,
#  'sharesShortPreviousMonthDate': None,
#  'sharesShortPriorMonth': None,
#  'shortName': 'TOYOTA MOTOR CORP',
#  'shortPercentOfFloat': None,
#  'shortRatio': None,
#  'startDate': None,
#  'strikePrice': None,
#  'symbol': '7203.T',
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 120,
#  'trailingAnnualDividendYield': 0.015993603,
#  'trailingEps': 507.402,
#  'trailingPE': 14.653075,
#  'twoHundredDayAverage': 6852.6357,
#  'volume': 5816400,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'http://global.toyota/en',
#  'yield': None,
#  'ytdReturn': None,
#  'zip': '471-8571'}

# %%
# !ls ../data
# Out:
# note.md  tse_allstock_20201030.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/tse_allstock_20201030.csv")
df
# Out:
#             日付   コード                                   銘柄名  \
# 0     20201030  1301                                    極洋
# 1     20201030  1305                         ダイワ上場投信－トピックス
# 2     20201030  1306               ＮＥＸＴ ＦＵＮＤＳ ＴＯＰＩＸ連動型上場投信
# 3     20201030  1308                     上場インデックスファンドＴＯＰＩＸ
# 4     20201030  1309  ＮＥＸＴ ＦＵＮＤＳ ＣｈｉｎａＡＭＣ・中国株式・上証５０連動型上場投信
# ...        ...   ...                                   ...
# 4054  20201030  9993                                  ヤマザワ
# 4055  20201030  9994                                   やまや
# 4056  20201030  9995                                 グローセル
# 4057  20201030  9996                                 サトー商会
# 4058  20201030  9997                                  ベルーナ
#
#                  市場・商品区分 33業種コード  33業種区分 17業種コード 17業種区分 規模コード           規模区分
# 0             市場第一部（内国株）      50  水産・農林業       1     食品     7  TOPIX Small 2
# 1                ETF・ETN       -       -       -      -     -              -
# 2                ETF・ETN       -       -       -      -     -              -
# 3                ETF・ETN       -       -       -      -     -              -
# 4                ETF・ETN       -       -       -      -     -              -
# ...                  ...     ...     ...     ...    ...   ...            ...
# 4054          市場第一部（内国株）    6100     小売業      14     小売     7  TOPIX Small 2
# 4055          市場第一部（内国株）    6100     小売業      14     小売     7  TOPIX Small 2
# 4056          市場第一部（内国株）    6050     卸売業      13  商社・卸売     7  TOPIX Small 2
# 4057  JASDAQ(スタンダード・内国株）    6050     卸売業      13  商社・卸売     -              -
# 4058          市場第一部（内国株）    6100     小売業      14     小売     6  TOPIX Small 1
#
# [4059 rows x 10 columns]
