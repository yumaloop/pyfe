# %%
import numpy as np
import pandas as pd
import yfinance as yf
from pprint import pprint

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
# トヨタ自動車
ticker = yf.Ticker("7203.T")

# %%
# Historical market data
#   Open - 始値
#   High - 高値
#   Low - 低値
#   Close - 終値
#   Volume - 発行株式総数
#   Dividends - 配当
#   Stock Splits - 株式分割)

hist = ticker.history(period="max")
hist
# Out:
#                   Open        High         Low       Close    Volume  \
# Date
# 2000-01-04  242.442310  245.457762  238.220678  241.236130   1806000
# 2000-01-05  243.648498  253.297943  241.839227  253.297943   2734000
# 2000-01-06  259.328814  276.215341  259.328814  273.199890   8390000
# 2000-01-07  286.467916  292.498820  284.658645  289.483368  10556000
# 2000-01-10  289.483368  289.483368  289.483368  289.483368         0
# ...                ...         ...         ...         ...       ...
# 2020-11-20  472.700012  485.799988  471.200012  485.799988  21605200
# 2020-11-24  500.000000  508.299988  494.799988  503.200012  32053600
# 2020-11-25  522.000000  547.599976  521.700012  538.200012  64407300
# 2020-11-26  533.500000  542.200012  521.799988  527.599976  35087100
# 2020-11-27  527.299988  528.700012  510.200012  517.200012  29191400
#
#             Dividends  Stock Splits
# Date
# 2000-01-04        0.0             0
# 2000-01-05        0.0             0
# 2000-01-06        0.0             0
# 2000-01-07        0.0             0
# 2000-01-10        0.0             0
# ...               ...           ...
# 2020-11-20        0.0             0
# 2020-11-24        0.0             0
# 2020-11-25        0.0             0
# 2020-11-26        0.0             0
# 2020-11-27        0.0             0
#
# [5240 rows x 7 columns]

# %% [markdown]
# ### 財務諸表

# %%
# 損益計算書
financials = ticker.financials
quarterly_financials = ticker.quarterly_financials

print("\n損益計算書 (年次)\n")
display(financials)
print("\n損益計算書 (四半期)\n")
display(quarterly_financials)
# Out:
# 損益計算書 (年次)
#                                          2020-03-31   2019-03-31   2018-03-31  \
# Research Development                           None         None         None
# Effect Of Accounting Charges                   None         None         None
# Income Before Tax                      -5.73022e+11  4.77708e+11  7.10743e+11
# Minority Interest                       3.60484e+11  3.20835e+11  3.03914e+11
# Net Income                             -6.71216e+11  3.19138e+11  7.46892e+11
# Selling General Administrative          1.30162e+12  1.44646e+12  1.41696e+12
# Gross Profit                            1.43596e+12  1.90384e+12  2.13717e+12
# Ebit                                    -4.0469e+10  3.18224e+11   5.7476e+11
# Operating Income                        -4.0469e+10  3.18224e+11   5.7476e+11
# Other Operating Expenses                       None         None         None
# Interest Expense                        -1.0874e+10  -1.3478e+10   -1.267e+10
# Extraordinary Items                            None         None         None
# Non Recurring                                  None         None         None
# Other Items                                    None         None         None
# Income Tax Expense                       9.3156e+10  1.35793e+11  -5.2914e+10
# Total Revenue                           9.87887e+12  1.15742e+13  1.19512e+13
# Total Operating Expenses                9.91934e+12   1.1256e+13  1.13764e+13
# Cost Of Revenue                         8.44290e+12   9.6704e+12    9.814e+12
# Total Other Income Expense Net         -5.32553e+11  1.59484e+11  1.35983e+11
# Discontinued Operations                        None         None         None
# Net Income From Continuing Ops         -6.66178e+11  3.41915e+11  7.63657e+11
# Net Income Applicable To Common Shares -6.71216e+11  3.19138e+11  7.46892e+11
#
#                                          2017-03-31
# Research Development                           None
# Effect Of Accounting Charges                   None
# Income Before Tax                       9.65157e+11
# Minority Interest                       3.04898e+11
# Net Income                              6.63499e+11
# Selling General Administrative          1.41412e+12
# Gross Profit                            2.29749e+12
# Ebit                                    7.42228e+11
# Operating Income                        7.42228e+11
# Other Operating Expenses                       None
# Interest Expense                        -1.4128e+10
# Extraordinary Items                            None
# Non Recurring                                  None
# Other Items                                    None
# Income Tax Expense                      2.64639e+11
# Total Revenue                             1.172e+13
# Total Operating Expenses                1.09778e+13
# Cost Of Revenue                         9.42255e+12
# Total Other Income Expense Net          2.22929e+11
# Discontinued Operations                        None
# Net Income From Continuing Ops          7.00518e+11
# Net Income Applicable To Common Shares  6.63499e+11
# 損益計算書 (四半期)
#                                          2020-09-30   2020-06-30   2020-03-31  \
# Research Development                           None         None         None
# Effect Of Accounting Charges                   None         None         None
# Income Before Tax                       -1.6333e+10 -3.04599e+11 -6.87492e+11
# Minority Interest                       3.51271e+11  3.48116e+11  3.60484e+11
# Net Income                               -4.437e+10 -2.85589e+11 -7.10489e+11
# Selling General Administrative          2.47125e+11  2.22441e+11  3.08012e+11
# Gross Profit                             2.6305e+11    9.862e+10  3.24206e+11
# Ebit                                     -4.833e+09 -1.53926e+11  -9.4812e+10
# Operating Income                         -4.833e+09 -1.53926e+11  -9.4812e+10
# Other Operating Expenses                  1.953e+10   1.4094e+10   1.4094e+10
# Interest Expense                          -5.59e+09    -2.97e+09   -2.455e+09
# Extraordinary Items                            None         None         None
# Non Recurring                                  None         None         None
# Other Items                                    None         None         None
# Income Tax Expense                       2.4266e+10  -2.0303e+10   3.0206e+10
# Total Revenue                           1.91849e+12  1.17419e+12  2.37158e+12
# Total Operating Expenses                1.92333e+12  1.32812e+12  2.46639e+12
# Cost Of Revenue                         1.65544e+12  1.07557e+12  2.04737e+12
# Total Other Income Expense Net            -1.15e+10 -1.50673e+11  -5.9268e+11
# Discontinued Operations                        None         None         None
# Net Income From Continuing Ops          -4.0599e+10 -2.84296e+11 -7.17698e+11
# Net Income Applicable To Common Shares   -4.437e+10 -2.85589e+11 -7.10489e+11
#
#                                          2019-12-31
# Research Development                           None
# Effect Of Accounting Charges                   None
# Income Before Tax                         9.751e+09
# Minority Interest                       3.69718e+11
# Net Income                              -2.6092e+10
# Selling General Administrative          2.70223e+11
# Gross Profit                            3.43563e+11
# Ebit                                     2.2735e+10
# Operating Income                         2.2735e+10
# Other Operating Expenses                 3.1309e+10
# Interest Expense                         -2.726e+09
# Extraordinary Items                            None
# Non Recurring                                  None
# Other Items                                    None
# Income Tax Expense                       3.1731e+10
# Total Revenue                           2.50421e+12
# Total Operating Expenses                2.48148e+12
# Cost Of Revenue                         2.16065e+12
# Total Other Income Expense Net          -1.2984e+10
# Discontinued Operations                        None
# Net Income From Continuing Ops           -2.198e+10
# Net Income Applicable To Common Shares  -2.6092e+10

# %%
# 貸借対照表
balance_sheet = ticker.balance_sheet
quarterly_balance_sheet = ticker.quarterly_balance_sheet

print("\n貸借対照表 (年次)\n")
display(balance_sheet)
print("\n貸借対照表 (四半期)\n")
display(quarterly_balance_sheet)
# Out:
# 貸借対照表 (年次)
#                                     2020-03-31    2019-03-31    2018-03-31  \
# Intangible Assets                 1.102880e+11  1.283300e+11  1.220630e+11
# Capital Surplus                   8.180560e+11  8.146820e+11  8.159130e+11
# Total Liab                        1.255194e+13  1.332884e+13  1.303822e+13
# Total Stockholder Equity          4.064289e+12  5.302675e+12  5.397796e+12
# Minority Interest                 3.604840e+11  3.208350e+11  3.039140e+11
# Other Current Liab                9.829410e+11  1.183573e+12  1.202701e+12
# Total Assets                      1.697671e+13  1.895234e+13  1.873994e+13
# Common Stock                      6.058140e+11  6.058140e+11  6.058140e+11
# Other Current Assets              7.393070e+11  9.454490e+11  7.757710e+11
# Retained Earnings                 4.125043e+12  4.961980e+12  4.921722e+12
# Other Liab                        1.272684e+12  1.351236e+12  1.336477e+12
# Good Will                         4.644000e+09  6.141000e+09  6.719000e+09
# Treasury Stock                   -1.484624e+12 -1.079801e+12 -9.456530e+11
# Other Assets                      4.898040e+11  5.601960e+11  5.505940e+11
# Cash                              1.295096e+12  1.171874e+12  1.073609e+12
# Total Current Liabilities         8.065246e+12  7.730531e+12  6.744384e+12
# Deferred Long Term Asset Charges  2.280120e+11  3.267590e+11  3.214260e+11
# Short Long Term Debt              2.592436e+12           NaN           NaN
# Other Stockholder Equity         -1.345362e+12 -9.403440e+11 -8.056830e+11
# Property Plant Equipment          2.107217e+12  2.598874e+12  2.624059e+12
# Total Current Assets              1.067594e+13  1.161310e+13  1.153039e+13
# Long Term Investments             1.170336e+12  1.334518e+12  1.262291e+12
# Net Tangible Assets               3.949357e+12  5.168204e+12  5.269014e+12
# Short Term Investments            2.605100e+11  1.394700e+11  7.120000e+10
# Net Receivables                   2.130230e+11  3.840560e+11  6.219770e+11
# Long Term Debt                    8.304800e+10  1.650000e+11  1.750000e+11
# Inventory                         1.340423e+12  1.257923e+12  1.290549e+12
# Accounts Payable                  1.333922e+12  1.532977e+12  1.599075e+12
#
#                                     2017-03-31
# Intangible Assets                 1.200430e+11
# Capital Surplus                   8.174640e+11
# Total Liab                        1.325387e+13
# Total Stockholder Equity          4.862238e+12
# Minority Interest                 3.048980e+11
# Other Current Liab                1.212714e+12
# Total Assets                      1.842101e+13
# Common Stock                      6.058140e+11
# Other Current Assets              9.031070e+11
# Retained Earnings                 4.349136e+12
# Other Liab                        1.582292e+12
# Good Will                         7.764000e+09
# Treasury Stock                   -9.101760e+11
# Other Assets                      3.967550e+11
# Cash                              1.075055e+12
# Total Current Liabilities         7.054220e+12
# Deferred Long Term Asset Charges  1.763540e+11
# Short Long Term Debt                       NaN
# Other Stockholder Equity         -7.694790e+11
# Property Plant Equipment          5.275221e+12
# Total Current Assets              1.146255e+13
# Long Term Investments             1.135752e+12
# Net Tangible Assets               4.734431e+12
# Short Term Investments            1.215240e+11
# Net Receivables                   6.995810e+11
# Long Term Debt                    3.206220e+11
# Inventory                         1.273161e+12
# Accounts Payable                  1.488771e+12
# 貸借対照表 (四半期)
#                                     2020-09-30    2020-06-30    2020-03-31  \
# Intangible Assets                 1.105150e+11  1.100290e+11  1.102880e+11
# Capital Surplus                   8.170720e+11  8.180590e+11  8.180560e+11
# Total Liab                        1.246774e+13  1.177613e+13  1.255194e+13
# Total Stockholder Equity          3.642031e+12  3.706587e+12  4.064289e+12
# Minority Interest                 3.512710e+11  3.481160e+11  3.604840e+11
# Deferred Long Term Liab           7.872000e+09           NaN           NaN
# Other Current Liab                8.664420e+11  9.117720e+11  9.829410e+11
# Total Assets                      1.646104e+13  1.583083e+13  1.697671e+13
# Common Stock                      6.058140e+11  6.058140e+11  6.058140e+11
# Other Current Assets              6.914160e+11  7.609240e+11  7.393070e+11
# Retained Earnings                 3.748194e+12  3.792600e+12  4.125043e+12
# Other Liab                        1.239372e+12  1.161446e+12  1.272684e+12
# Treasury Stock                   -1.529049e+12 -1.509886e+12 -1.484624e+12
# Other Assets                      7.872000e+09           NaN  4.898040e+11
# Cash                              2.127952e+12  1.334759e+12  1.295096e+12
# Total Current Liabilities         6.692354e+12  6.855704e+12  8.065246e+12
# Short Long Term Debt              2.401364e+12  2.422053e+12  2.592436e+12
# Other Stockholder Equity         -1.389764e+12 -1.370140e+12 -1.345362e+12
# Property Plant Equipment          4.297421e+12  4.382848e+12  2.107217e+12
# Total Current Assets              1.042396e+13  9.757237e+12  1.067594e+13
# Long Term Investments             1.621273e+12  1.580719e+12  1.170336e+12
# Net Tangible Assets               3.531516e+12  3.596558e+12  3.949357e+12
# Short Term Investments            3.511110e+11  1.259750e+11  2.605100e+11
# Net Receivables                   6.137150e+12  6.333257e+12  2.130230e+11
# Long Term Debt                    4.461215e+12  3.682095e+12  8.304800e+10
# Inventory                         1.116333e+12  1.202322e+12  1.340423e+12
# Accounts Payable                  1.131059e+12  7.814900e+11  1.333922e+12
# Good Will                                  NaN           NaN  4.644000e+09
# Deferred Long Term Asset Charges           NaN           NaN  2.280120e+11
#
#                                     2019-12-31
# Intangible Assets                 1.216410e+11
# Capital Surplus                   8.180560e+11
# Total Liab                        1.266743e+13
# Total Stockholder Equity          5.051448e+12
# Minority Interest                 3.697180e+11
# Deferred Long Term Liab                    NaN
# Other Current Liab                1.021060e+12
# Total Assets                      1.808860e+13
# Common Stock                      6.058140e+11
# Other Current Assets              8.257680e+11
# Retained Earnings                 4.835532e+12
# Other Liab                        1.304637e+12
# Treasury Stock                   -1.207954e+12
# Other Assets                      5.888280e+11
# Cash                              1.204178e+12
# Total Current Liabilities         7.586005e+12
# Short Long Term Debt              2.350680e+12
# Other Stockholder Equity         -1.068682e+12
# Property Plant Equipment          5.197848e+12
# Total Current Assets              1.097389e+13
# Long Term Investments             1.795216e+12
# Net Tangible Assets               4.929807e+12
# Short Term Investments            2.143270e+11
# Net Receivables                   7.293218e+12
# Long Term Debt                    3.698822e+12
# Inventory                         1.436402e+12
# Accounts Payable                  1.407632e+12
# Good Will                                  NaN
# Deferred Long Term Asset Charges           NaN

# %%
# キャッシュフロー計算書
cashflow = ticker.cashflow
quarterly_cashflow = ticker.quarterly_cashflow

print("\nキャッシュフロー計算書 (年次)\n")
display(cashflow)
print("\nキャッシュフロー計算書 (四半期)\n")
display(quarterly_cashflow)
# Out:
# キャッシュフロー計算書 (年次)
#                                              2020-03-31    2019-03-31  \
# Investments                               -8.254000e+09 -3.047500e+10
# Change To Liabilities                     -2.556860e+11 -4.372100e+10
# Total Cashflows From Investing Activities -7.086870e+11 -1.133547e+12
# Net Borrowings                            -2.325000e+09  1.033330e+11
# Total Cash From Financing Activities      -1.554940e+11 -1.271400e+11
# Change To Operating Activities             6.883800e+11  9.063400e+10
# Net Income                                -6.712160e+11  3.191380e+11
# Change In Cash                             2.839230e+11  1.530580e+11
# Repurchase Of Stock                       -2.000000e+06 -5.000000e+06
# Effect Of Exchange Rate                   -4.395400e+10 -3.825800e+10
# Total Cash From Operating Activities       1.185854e+12  1.450888e+12
# Depreciation                               3.857970e+11  3.868550e+11
# Other Cashflows From Investing Activities  8.469400e+10 -1.442430e+11
# Dividends Paid                            -1.506520e+11 -2.151010e+11
# Change To Inventory                       -1.185780e+11  1.309800e+10
# Change To Account Receivables              1.418820e+11  2.280100e+11
# Other Cashflows From Financing Activities -2.515000e+09 -1.536700e+10
# Change To Netincome                        5.334760e+11 -5.693000e+10
# Capital Expenditures                      -1.579069e+12 -1.721271e+12
# Issuance Of Stock                                   NaN           NaN
#
#                                              2018-03-31    2017-03-31
# Investments                               -1.217100e+10 -2.723470e+11
# Change To Liabilities                      1.083300e+11  2.960600e+11
# Total Cashflows From Investing Activities -1.147719e+12 -1.377626e+12
# Net Borrowings                             2.630300e+11  8.793790e+11
# Total Cash From Financing Activities       3.681000e+10  3.206100e+11
# Change To Operating Activities            -5.182840e+11 -7.429350e+11
# Net Income                                 7.468920e+11  6.634990e+11
# Change In Cash                            -3.512400e+10  2.490290e+11
# Repurchase Of Stock                       -6.000000e+06 -2.774190e+11
# Effect Of Exchange Rate                    4.535000e+09 -3.487500e+10
# Total Cash From Operating Activities       1.071250e+12  1.335473e+12
# Depreciation                               3.894840e+11  3.936160e+11
# Other Cashflows From Investing Activities  8.724000e+09 -3.500000e+07
# Dividends Paid                            -1.975410e+11 -1.828030e+11
# Change To Inventory                        9.612000e+09 -3.266000e+10
# Change To Account Receivables              7.314900e+10 -4.258400e+10
# Other Cashflows From Financing Activities -3.003000e+10 -9.867500e+10
# Change To Netincome                       -2.387370e+11  3.512180e+11
# Capital Expenditures                      -1.829358e+12 -1.797585e+12
# Issuance Of Stock                          1.357000e+09  1.280000e+08
# キャッシュフロー計算書 (四半期)
#                                              2020-09-30    2020-06-30  \
# Investments                                1.580500e+10 -9.349800e+10
# Change To Liabilities                      2.980870e+11 -6.360650e+11
# Total Cashflows From Investing Activities -8.326300e+10 -2.060850e+11
# Net Borrowings                             4.165590e+11  1.934600e+10
# Total Cash From Financing Activities       3.890360e+11  1.017600e+10
# Change To Operating Activities            -5.536850e+11  5.155710e+11
# Net Income                                -4.437000e+10 -2.855890e+11
# Change In Cash                             1.018329e+12 -1.822470e+11
# Effect Of Exchange Rate                    2.207000e+09 -6.877000e+09
# Total Cash From Operating Activities       7.103490e+11  2.053900e+10
# Depreciation                               1.703930e+11  1.945050e+11
# Other Cashflows From Investing Activities -7.960000e+08  1.030000e+08
# Change To Inventory                        9.467400e+10  1.470180e+11
# Change To Account Receivables              6.631580e+11  4.584100e+10
# Other Cashflows From Financing Activities -2.752300e+10 -9.170000e+09
# Change To Netincome                        5.405500e+10  5.826800e+10
# Capital Expenditures                      -3.126640e+11 -2.550970e+11
# Repurchase Of Stock                                 NaN           NaN
# Dividends Paid                                      NaN           NaN
#
#                                              2020-03-31    2019-12-31
# Investments                                2.519000e+09 -3.688000e+10
# Change To Liabilities                      7.247500e+10 -1.958510e+11
# Total Cashflows From Investing Activities -1.857530e+11 -2.264030e+11
# Net Borrowings                             5.860300e+10  1.156200e+11
# Total Cash From Financing Activities       5.942700e+10  6.586700e+10
# Change To Operating Activities             1.169390e+11  1.200400e+11
# Net Income                                -7.104890e+11 -2.609200e+10
# Change In Cash                             2.244760e+11  7.034900e+10
# Effect Of Exchange Rate                   -2.476900e+10  4.640000e+09
# Total Cash From Operating Activities       3.755710e+11  2.260920e+11
# Depreciation                               9.765900e+10  2.185640e+11
# Other Cashflows From Investing Activities -2.902800e+10 -5.360000e+08
# Change To Inventory                        4.623300e+10 -9.071000e+09
# Change To Account Receivables              3.579500e+10  8.104300e+10
# Other Cashflows From Financing Activities  8.240000e+08 -1.062000e+10
# Change To Netincome                        5.992030e+11  1.616000e+09
# Capital Expenditures                      -3.519910e+11 -3.808090e+11
# Repurchase Of Stock                                 NaN -1.000000e+06
# Dividends Paid                                      NaN -3.913200e+10

# %%
# show major holders
ticker.major_holders
# Out:
#         0                                      1
# 0  47.10%        % of Shares Held by All Insider
# 1  12.25%       % of Shares Held by Institutions
# 2  23.16%        % of Float Held by Institutions
# 3     266  Number of Institutions Holding Shares

# %%
# show institutional holders
ticker.institutional_holders
# Out:
#                                               Holder    Shares Date Reported  \
# 0  Vanguard International Stock Index-Total Intl ...  32686714    2020-07-31
# 1  Vanguard Tax Managed Fund-Vanguard Developed M...  12287508    2020-06-30
# 2                         iShares Core MSCI EAFE ETF  10122100    2020-09-30
# 3                              iShares MSCI Eafe ETF   7949100    2020-09-30
# 4                             iShares MSCI Japan ETF   6345900    2020-09-30
# 5                     DFA International Value Series   5826900    2020-07-31
# 6            American Beacon International Equity Fd   5042200    2020-07-31
# 7                  Fidelity International Index Fund   4423548    2020-08-31
# 8  Vanguard Intl Equity Index Fds-FTSE All World ...   3466339    2020-07-31
# 9            JP Morgan ETF Tr-BetaBuilders Japan ETF   3267700    2020-10-31
#
#     % Out        Value
# 0  0.0077  11799903754
# 1  0.0029   4905173193
# 2  0.0024   3763396780
# 3  0.0019   2955475380
# 4  0.0015   2359405620
# 5  0.0014   2103510900
# 6  0.0012   1820234200
# 7  0.0010   1908760962
# 8  0.0008   1251348379
# 9  0.0008   1195978200

# %%
# 銘柄サマリ
info = ticker.info
pprint(info)
# Out:
# {'52WeekChange': -0.24858344,
#  'SandP52WeekChange': 0.16843343,
#  'address1': '1-1, Takashima 1-chome',
#  'address2': 'Nishi-ku',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 517.5,
#  'askSize': 0,
#  'averageDailyVolume10Day': 35407000,
#  'averageVolume': 19814893,
#  'averageVolume10days': 35407000,
#  'beta': 1.322001,
#  'beta3Year': None,
#  'bid': 517.1,
#  'bidSize': 0,
#  'bookValue': 930.738,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Yokohama',
#  'companyOfficers': [],
#  'country': 'Japan',
#  'currency': 'JPY',
#  'dateShortInterest': None,
#  'dayHigh': 528.7,
#  'dayLow': 510.2,
#  'dividendRate': None,
#  'dividendYield': None,
#  'earningsQuarterlyGrowth': None,
#  'enterpriseToEbitda': 95.479,
#  'enterpriseToRevenue': 1.033,
#  'enterpriseValue': 8234293264384,
#  'exDividendDate': 1569542400,
#  'exchange': 'JPX',
#  'exchangeTimezoneName': 'Asia/Tokyo',
#  'exchangeTimezoneShortName': 'JST',
#  'expireDate': None,
#  'fiftyDayAverage': 416.00293,
#  'fiftyTwoWeekHigh': 689.5,
#  'fiftyTwoWeekLow': 311.2,
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': None,
#  'floatShares': 2080884999,
#  'forwardEps': 146.57,
#  'forwardPE': 3.5286894,
#  'fromCurrency': None,
#  'fullTimeEmployees': 136134,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '32400000',
#  'heldPercentInsiders': 0.47103,
#  'heldPercentInstitutions': 0.12252,
#  'industry': 'Auto Manufacturers',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendDate': 1569542400,
#  'lastDividendValue': 10,
#  'lastFiscalYearEnd': 1585612800,
#  'lastMarket': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/nissan-global.com',
#  'longBusinessSummary': 'Nissan Motor Co., Ltd. manufactures and sells '
#                         'vehicles and automotive parts worldwide. It sells '
#                         'vehicles under the Nissan, Infiniti, Datsun, '
#                         'Heritage, and Motorsports brands. The company offers '
#                         'vehicle and vehicle parts; engines, manual '
#                         'transmissions, and multiplier/reducer units; '
#                         'automotive parts; axles; specially equipped vehicles; '
#                         'and motorsports engines. It also provides financial '
#                         'services, auto credit and car leasing, card business, '
#                         'insurance agency, and inventory finance, as well as '
#                         'engages in exterior and interior design for '
#                         'automobiles, and operations and consulting related to '
#                         'the analysis and assay of raw materials. In addition, '
#                         'the company engages in the provision of travel, '
#                         'environmental and engineering, production technology '
#                         'center, and facility services; ground and vehicle '
#                         'management, and information and logistics businesses; '
#                         'design, vehicle drawings and experiments, other '
#                         'engineering, electronic devices, and electronic '
#                         'equipment businesses; export and import of auto '
#                         'components and materials; and real estate businesses. '
#                         'Further, it is involved in promotion of motorsports, '
#                         'including race and motorsports event planning, and '
#                         'vehicle remodeling; sale of car parts and accessories '
#                         'for motorsports; and demonstration test and '
#                         'commercialization study for second-life use of '
#                         'lithium-ion batteries for automotive use. '
#                         'Additionally, the company imports and sells Renault '
#                         'vehicles and parts; and manages and plans '
#                         'professional soccer team and soccer schools. The '
#                         'company was founded in 1933 and is headquartered in '
#                         'Yokohama, Japan.',
#  'longName': 'Nissan Motor Co., Ltd.',
#  'market': 'jp_market',
#  'marketCap': 2023239843840,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_291331',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1601424000,
#  'navPrice': None,
#  'netIncomeToCommon': -1066540007424,
#  'nextFiscalYearEnd': 1648684800,
#  'open': 527.3,
#  'openInterest': None,
#  'payoutRatio': 0,
#  'pegRatio': None,
#  'phone': '81 45 523 5523',
#  'previousClose': 527.6,
#  'priceHint': 2,
#  'priceToBook': 0.5556881,
#  'priceToSalesTrailing12Months': 0.25390542,
#  'profitMargins': -0.13384,
#  'quoteType': 'EQUITY',
#  'regularMarketDayHigh': 528.7,
#  'regularMarketDayLow': 510.2,
#  'regularMarketOpen': 527.3,
#  'regularMarketPreviousClose': 527.6,
#  'regularMarketPrice': 527.3,
#  'regularMarketVolume': 29191400,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Consumer Cyclical',
#  'sharesOutstanding': 3911909888,
#  'sharesPercentSharesOut': None,
#  'sharesShort': None,
#  'sharesShortPreviousMonthDate': None,
#  'sharesShortPriorMonth': None,
#  'shortName': 'NISSAN MOTOR CO',
#  'shortPercentOfFloat': None,
#  'shortRatio': None,
#  'startDate': None,
#  'strikePrice': None,
#  'symbol': '7201.T',
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 0,
#  'trailingAnnualDividendYield': 0,
#  'trailingEps': -272.58,
#  'twoHundredDayAverage': 407.76242,
#  'volume': 29191400,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'http://www.nissan-global.com',
#  'yield': None,
#  'ytdReturn': None,
#  'zip': '220-8686'}

# %% [markdown]
# - marketCap(時価総額)
# - sharesOutstanding(発行株数)
# - forwardPE(予測PER)
# - dividendYield(配当利回り)
# - profitMargins(純利益比率)
