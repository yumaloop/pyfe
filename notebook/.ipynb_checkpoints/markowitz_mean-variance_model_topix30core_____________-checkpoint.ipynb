# %%
import numpy as np
import pandas as pd

import yfinance as yf
import pandas_datareader

from datetime import datetime
from pprint import pprint

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
style.use('seaborn') # style.use('ggplot') # style.use('fivethirtyeight')
# %matplotlib inline

# %%
df_topix30 = pd.read_csv("../data/tse_topixcore30_20201030.csv")
df_topix30.head()
# Out:
#          日付   コード              銘柄名     市場・商品区分  33業種コード 33業種区分  17業種コード  \
# 0  20201030  3382  セブン＆アイ・ホールディングス  市場第一部（内国株）     6100    小売業       14
# 1  20201030  4063           信越化学工業  市場第一部（内国株）     3200     化学        4
# 2  20201030  4452               花王  市場第一部（内国株）     3200     化学        4
# 3  20201030  4502           武田薬品工業  市場第一部（内国株）     3250    医薬品        5
# 4  20201030  4503          アステラス製薬  市場第一部（内国株）     3250    医薬品        5
#
#   17業種区分  規模コード          規模区分
# 0     小売      1  TOPIX Core30
# 1  素材・化学      1  TOPIX Core30
# 2  素材・化学      1  TOPIX Core30
# 3    医薬品      1  TOPIX Core30
# 4    医薬品      1  TOPIX Core30

# %%
stocks_topix30 = df_topix30['コード'].values
stocks_topix30
# Out:
# array([3382, 4063, 4452, 4502, 4503, 4568, 6098, 6367, 6501, 6594, 6758,
#        6861, 6954, 6981, 7203, 7267, 7741, 7974, 8001, 8031, 8058, 8306,
#        8316, 8411, 8766, 9022, 9432, 9433, 9437, 9984])

# %%
st = '2013/1/1'   # st = datetime(2015, 10, 30)
ed = '2018/12/31' # ed = datetime(2020, 10, 30)

symbols =  [str(s)+'.T' for s in stocks_topix30]
# symbols.append('^N225')
# symbols.append('TOPIX')

dfs = []
for symbol in symbols:
    df = pandas_datareader.data.DataReader(symbol, 'yahoo', st, ed) # daily
    df = df.resample('M').mean() # daily -> monthly
    df = df.sort_values(by='Date', ascending=True)
    df = df.fillna(method='ffill') # 1つ前の行の値で埋める
    df = df[['Close']].rename(columns={'Close': symbol})
    dfs.append(df)

df = pd.concat(dfs, axis=1)

# %%
display(df.head(3))
display(df.tail(3))
# Out:
#                  3382.T       4063.T       4452.T       4502.T       4503.T  \
# Date
# 2013-01-31  2664.526316  5442.631579  2416.736842  4360.263158   876.842105
# 2013-02-28  2782.842105  5612.631579  2849.947368  4710.789474   972.052632
# 2013-03-31  2954.900000  6051.000000  3091.500000  5107.500000  1028.900000
#
#                 4568.T  6098.T       6367.T       6501.T       6594.T  ...  \
# Date                                                                   ...
# 2013-01-31  483.929842     NaN  3185.842105  2691.842105  2621.578947  ...
# 2013-02-28  533.456106     NaN  3530.000000  2634.473684  2657.631579  ...
# 2013-03-31  599.933350     NaN  3755.500000  2730.000000  2779.500000  ...
#
#                  8058.T      8306.T       8316.T       8411.T       8766.T  \
# Date
# 2013-01-31  1805.789474  479.578947  3301.315789  1689.473684  2604.157895
# 2013-02-28  1901.473684  524.789474  3753.947368  2025.263158  2708.947368
# 2013-03-31  1829.950000  556.500000  3927.750000  2077.500000  2770.650000
#
#                  9022.T       9432.T       9433.T       9437.T       9984.T
# Date
# 2013-01-31  7462.631579   935.986842  1047.279991  1305.315789  1520.394737
# 2013-02-28  8541.052632  1038.947368  1144.912103  1394.421053  1713.552632
# 2013-03-31  9788.500000  1054.875000  1224.665485  1453.500000  1903.375000
#
# [3 rows x 30 columns]
#                  3382.T       4063.T       4452.T       4502.T       4503.T  \
# Date
# 2018-10-31  4917.173913  9283.913043  8286.478261  4547.565217  1865.630435
# 2018-11-30  4961.272727  9843.363636  7919.681818  4427.409091  1690.863636
# 2018-12-31  4827.571429  9035.571429  8179.761905  3856.714286  1567.690476
#
#                  4568.T       6098.T        6367.T       6501.T        6594.T  \
# Date
# 2018-10-31  1532.362613  3368.891304  13939.782609  3524.826087  14875.652174
# 2018-11-30  1385.879555  2984.704545  12402.045455  3374.000000  14379.090909
# 2018-12-31  1292.015712  2886.833333  12125.000000  3127.928571  13488.809524
#
#             ...       8058.T      8306.T       8316.T       8411.T  \
# Date        ...
# 2018-10-31  ...  3414.347826  691.091301  4472.695652  1940.086957
# 2018-11-30  ...  3078.340909  653.668188  4308.090909  1920.181818
# 2018-12-31  ...  3041.142857  572.714289  3851.476190  1771.761905
#
#                  8766.T        9022.T       9432.T       9433.T       9437.T  \
# Date
# 2018-10-31  5427.869565  22321.956522  2477.434783  2944.304348  2918.391304
# 2018-11-30  5495.181818  22115.454545  2270.340909  2526.340909  2568.159091
# 2018-12-31  5338.952381  22790.000000  2271.452381  2624.023810  2516.333333
#
#                  9984.T
# Date
# 2018-10-31  4923.630435
# 2018-11-30  4459.181818
# 2018-12-31  4156.595238
#
# [3 rows x 30 columns]

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(df.corr(), annot=True, square=True, fmt='.1f')
plt.show()

# %%
def calc_returns(df):
    """
    calculate change ratio of returns && cumulative returns
    """
    # df = df.fillna(method='ffill')

    # 収益率(returns change)
    df_retchg = df.pct_change()
    df_retchg[:1] = 0.0 # 最初の行を0.0に直す
    
    # 累積収益率 (cumulative returns)
    df_retcum = (1 + df_retchg).cumprod()
    df_retcum[:1] = 1.0 # 最初の行を1.0に直す
    
    return df_retcum, df_retchg

# %%
df_retcum, df_retchg = calc_returns(df)

display(df_retchg.head(3))
display(df_retchg.tail(3))

display(df_retcum.head(3))
display(df_retcum.tail(3))
# Out:
#               3382.T    4063.T    4452.T    4502.T    4503.T    4568.T  \
# Date
# 2013-01-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-02-28  0.044404  0.031235  0.179254  0.080391  0.108583  0.102342
# 2013-03-31  0.061828  0.078104  0.084757  0.084213  0.058482  0.124616
#
#             6098.T    6367.T    6501.T    6594.T  ...    8058.T    8306.T  \
# Date                                              ...
# 2013-01-31     0.0  0.000000  0.000000  0.000000  ...  0.000000  0.000000
# 2013-02-28     NaN  0.108027 -0.021312  0.013752  ...  0.052987  0.094271
# 2013-03-31     NaN  0.063881  0.036260  0.045856  ... -0.037615  0.060425
#
#               8316.T    8411.T    8766.T    9022.T    9432.T    9433.T  \
# Date
# 2013-01-31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2013-02-28  0.137106  0.198754  0.040239  0.144509  0.110002  0.093224
# 2013-03-31  0.046299  0.025793  0.022777  0.146053  0.015331  0.069659
#
#               9437.T    9984.T
# Date
# 2013-01-31  0.000000  0.000000
# 2013-02-28  0.068263  0.127045
# 2013-03-31  0.042368  0.110777
#
# [3 rows x 30 columns]
#               3382.T    4063.T    4452.T    4502.T    4503.T    4568.T  \
# Date
# 2018-10-31  0.013600 -0.052734 -0.061618 -0.024504 -0.024290  0.002571
# 2018-11-30  0.008968  0.060260 -0.044264 -0.026422 -0.093677 -0.095593
# 2018-12-31 -0.026949 -0.082065  0.032840 -0.128900 -0.072846 -0.067729
#
#               6098.T    6367.T    6501.T    6594.T  ...    8058.T    8306.T  \
# Date                                                ...
# 2018-10-31 -0.055274 -0.052038 -0.043765 -0.074811  ...  0.029286  0.001255
# 2018-11-30 -0.114040 -0.110313 -0.042790 -0.033381  ... -0.098410 -0.054151
# 2018-12-31 -0.032791 -0.022339 -0.072932 -0.061915  ... -0.012084 -0.123846
#
#               8316.T    8411.T    8766.T    9022.T    9432.T    9433.T  \
# Date
# 2018-10-31  0.002993 -0.012578  0.017303 -0.016047 -0.011961 -0.030075
# 2018-11-30 -0.036802 -0.010260  0.012401 -0.009251 -0.083592 -0.141957
# 2018-12-31 -0.105990 -0.077295 -0.028430  0.030501  0.000490  0.038666
#
#               9437.T    9984.T
# Date
# 2018-10-31 -0.014831 -0.074227
# 2018-11-30 -0.120009 -0.094331
# 2018-12-31 -0.020180 -0.067857
#
# [3 rows x 30 columns]
#               3382.T    4063.T    4452.T    4502.T    4503.T    4568.T  \
# Date
# 2013-01-31  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2013-02-28  1.044404  1.031235  1.179254  1.080391  1.108583  1.102342
# 2013-03-31  1.108978  1.111778  1.279204  1.171374  1.173415  1.239711
#
#             6098.T    6367.T    6501.T    6594.T  ...    8058.T    8306.T  \
# Date                                              ...
# 2013-01-31     1.0  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2013-02-28     NaN  1.108027  0.978688  1.013752  ...  1.052987  1.094271
# 2013-03-31     NaN  1.178809  1.014175  1.060239  ...  1.013379  1.160393
#
#               8316.T    8411.T    8766.T    9022.T    9432.T    9433.T  \
# Date
# 2013-01-31  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2013-02-28  1.137106  1.198754  1.040239  1.144509  1.110002  1.093224
# 2013-03-31  1.189753  1.229673  1.063933  1.311669  1.127019  1.169377
#
#               9437.T    9984.T
# Date
# 2013-01-31  1.000000  1.000000
# 2013-02-28  1.068263  1.127045
# 2013-03-31  1.113524  1.251895
#
# [3 rows x 30 columns]
#               3382.T    4063.T    4452.T    4502.T    4503.T    4568.T  \
# Date
# 2018-10-31  1.845421  1.705776  3.428788  1.042957  2.127670  3.166497
# 2018-11-30  1.861972  1.808567  3.277015  1.015400  1.928356  2.863803
# 2018-12-31  1.811793  1.660148  3.384631  0.884514  1.787882  2.669841
#
#               6098.T    6367.T    6501.T    6594.T  ...    8058.T    8306.T  \
# Date                                                ...
# 2018-10-31  2.764532  4.375541  1.309448  5.674310  ...  1.890778  1.441038
# 2018-11-30  2.449266  3.892863  1.253417  5.484897  ...  1.704706  1.363004
# 2018-12-31  2.368953  3.805901  1.162003  5.145300  ...  1.684107  1.194202
#
#               8316.T    8411.T    8766.T    9022.T    9432.T    9433.T  \
# Date
# 2018-10-31  1.354822  1.148338  2.084309  2.991164  2.646869  2.811382
# 2018-11-30  1.304962  1.136556  2.110157  2.963493  2.425612  2.412288
# 2018-12-31  1.166649  1.048706  2.050165  3.053883  2.426799  2.505561
#
#               9437.T    9984.T
# Date
# 2018-10-31  2.235774  3.238390
# 2018-11-30  1.967462  2.932911
# 2018-12-31  1.927758  2.733892
#
# [3 rows x 30 columns]

# %%
plt.figure(figsize=(12, 8))
for idx, col in enumerate(df.columns):
    plt.plot(df_retchg.index, df_retchg[col], label=col, alpha=0.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
plt.figure(figsize=(12, 8))
for idx, col in enumerate(df.columns):
    plt.plot(df_retcum.index, df_retcum[col], label=col, alpha=0.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
plt.figure(figsize=(12, 8))
for idx, col in enumerate(df.columns):
    plt.hist(df_retchg[[col]], label=col, alpha=0.5)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()

# %%
for idx, col in enumerate(df.columns):
    plt.hist(df_retchg[[col]].values, bins=20, label=col, alpha=0.75)
    plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.xlim([-0.25, 0.45])
    if (idx + 1) % 5 == 0:
        plt.show()

# %%
# cumulative returns
plt.figure(figsize=(12,8))
plt.bar(df_retchg.columns, df_retcum.iloc[-1].values)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# expected returns
plt.figure(figsize=(12,8))
plt.bar(df_retcum.columns, df_retchg.mean().values)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# variance
plt.figure(figsize=(12,8))
plt.bar(df_retcum.columns, df_retchg.var().values)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
# returns vs risk (change)
plt.figure(figsize=(10,10))
mean = df_retchg.mean().values
var = df_retchg.var().values
plt.scatter(var, mean)
plt.xlabel("Risk (variance)")
plt.ylabel("Return (mean)")
plt.show()

# %%
# returns vs risk (cumulative)
plt.figure(figsize=(10,10))
mean = df_retcum.mean().values
var = df_retcum.var().values
plt.scatter(var, mean)
plt.xlabel("Risk (variance)")
plt.ylabel("Return (mean)")
plt.show()

# %% [markdown]
# ### ポートフォリオ選択モデル

# %% [markdown]
# Markowitzの平均分散モデル
#
# - $\Sigma  \in \mathbb{R}^{n \times n}$: 共分散行列
# - $r  \in \mathbb{R}^{n}$: 期待収益率ベクトル
# - $r_i \in \mathbb{R}$: 資産$i$の期待収益率
# - $r_e \in \mathbb{R}$: 投資家の要求期待収益率
# - $x \in \mathbb{R}^{n}$: 投資比率ベクトル
# - $x_i \in \mathbb{R}$: 資産$i$の投資比率
#
#
# $$
# \begin{align}
# {\rm min} ~~~ x^T \Sigma x \\
# {\rm s.t.} ~~~ r^T x \geq r_e \\
# {\| x \|}_{1} = 1 \\
# x_i \geq 0
# \end{align}
# $$
#
# *二次計画問題
#
# ![img0](https://cdn-ak.f.st-hatena.com/images/fotolife/m/meison_amsl/20161016/20161016122314.png)
#
#
# 参考:
# - https://cvxopt.org/userguide/coneprog.html
# - https://qiita.com/ryoshi81/items/8b0c6add3e367f94c828

# %%
import cvxopt

def cvxopt_qp_solver(r, r_e, cov):
    # CVXOPT QP Solver for Markowitz' Mean-Variance Model
    # See https://cvxopt.org/userguide/coneprog.html#quadratic-programming
    # See https://cdn.hackaday.io/files/277521187341568/art-mpt.pdf
    n = len(r)
    r = cvxopt.matrix(r)
    
    P = cvxopt.matrix(2.0 * np.array(cov))
    q = cvxopt.matrix(np.zeros((n, 1)))
    G = cvxopt.matrix(np.concatenate((-np.transpose(r), -np.identity(n)), 0))
    h = cvxopt.matrix(np.concatenate((-np.ones((1,1)) * r_e, np.zeros((n,1))), 0))
    A = cvxopt.matrix(1.0, (1, n))
    b = cvxopt.matrix(1.0)    
    sol = cvxopt.solvers.qp(P, q, G, h, A, b)
    return sol

# %%
r = df_retchg.mean().values
r_e = 0.01
cov = np.array(df_retcum.cov())

sol = cvxopt_qp_solver(r, r_e, cov)
x_opt = np.squeeze(np.array(sol['x']))
print(x_opt)
print("min var (opt) :", sol["primal objective"])
print("r_e           :", r_e)
# Out:
#      pcost       dcost       gap    pres   dres
#  0:  7.7932e-03 -9.9242e-01  4e+01  6e+00  6e+00
#  1:  2.2073e-02 -8.9392e-01  2e+00  2e-01  2e-01
#  2:  6.3952e-02 -2.5521e-01  3e-01  9e-03  9e-03
#  3:  1.0410e-01 -9.7840e-02  2e-01  3e-03  3e-03
#  4:  7.1377e-02  8.9479e-03  6e-02  6e-17  8e-16
#  5:  4.6337e-02  1.5457e-02  3e-02  1e-16  2e-15
#  6:  3.8477e-02  3.2441e-02  6e-03  3e-17  6e-16
#  7:  3.6085e-02  3.4832e-02  1e-03  2e-16  2e-15
#  8:  3.5223e-02  3.5192e-02  3e-05  2e-16  8e-15
#  9:  3.5200e-02  3.5200e-02  4e-07  1e-16  7e-14
# 10:  3.5200e-02  3.5200e-02  4e-09  1e-16  2e-13
# Optimal solution found.
# [6.10327099e-01 2.12317777e-09 9.25049251e-10 3.46179872e-09
#  1.40726905e-08 1.39381031e-09 1.93276023e-01 6.37811068e-10
#  7.48578628e-09 2.81562653e-10 4.20016847e-10 3.66984887e-10
#  2.19744809e-09 1.05625553e-09 2.17181443e-02 6.00999549e-09
#  7.87662390e-10 4.08552747e-10 2.54642821e-09 4.07668415e-09
#  3.41282179e-09 5.70755874e-09 4.97701415e-07 1.74678163e-01
#  3.06196827e-09 2.15107112e-09 1.42617203e-09 2.92232077e-09
#  2.55105300e-09 3.67687296e-09]
# min var (opt) : 0.035199682690894005
# r_e           : 0.01

# %%
# Opt portfolio
plt.figure(figsize=(12,8))
plt.bar(df.columns, x_opt)
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
meanchg = df_retchg.mean().values
meanchg_opt = float(np.dot(meanchg, x_opt))

meancum = df_retcum.iloc[-1].values
meancum_opt = float(np.dot(meancum, x_opt))

varchg = df_retchg.var().values
varchg_opt = float(np.dot(varchg, x_opt ** 2))

varcum = df_retcum.var().values
varcum_opt = float(np.dot(varcum, x_opt ** 2))

print("opt portfolio\n=============")
print("mean chg :", meanchg_opt)
print("var chg  :", varchg_opt)
print("mean cum :", meancum_opt)
print("var cum  :", varcum_opt)
# Out:
# opt portfolio
# =============
# mean chg : 0.01000000001126379
# var chg  : 0.0012163693731041506
# mean cum : 1.7809179999267508
# var cum  : 0.03432601591810997

# %%
# returns vs risk (change)
plt.figure(figsize=(10,10))
plt.scatter(varchg, meanchg)
plt.scatter(varchg_opt, meanchg_opt, marker="o", color="red")
plt.title("returns vs risk (change)")
plt.xlabel("Risk (variance)")
plt.ylabel("Return (mean)")
plt.show()

# %%
# returns vs risk (cumulative)
plt.figure(figsize=(10,10))
plt.scatter(varcum, meancum)
plt.scatter(varcum_opt, meancum_opt, marker="o", color="red")
plt.title("returns vs risk (cumulative)")
plt.xlabel("Risk (variance)")
plt.ylabel("Return (mean)")
plt.show()
