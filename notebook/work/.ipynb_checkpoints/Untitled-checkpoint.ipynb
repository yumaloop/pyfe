# %%
import pandas_datareader
import pandas as pd
import yfinance as yf

from pprint import pprint

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;

# %%
stocks_topix30 = [2914, 3382, 4063, 4452, 4502, 
                  4503, 5401, 6301, 6501, 6502, 
                  6752, 6758, 6954, 7201, 7203, 
                  7267, 7751, 8031, 8058, 8306, 
                  8316, 8411, 8604, 8766, 8802, 
                  9021, 9432, 9433, 9437, 9984]

symbols = [str(s)+'.T' for s in stocks_topix30]
symbols

# %%
for idx, symbol in enumerate(symbols):
    ticker = yf.Ticker(symbol)
    d = {k: pd.Series(v, dtype='object') for k, v in ticker.info.items()}
    df_one = pd.DataFrame(d)
    df = df_one if idx == 0 else df.append(df_one, ignore_index=True)

# %%
df
# Out:
#          zip                  sector fullTimeEmployees  \
# 0   105-8422      Consumer Defensive             61975
# 1   102-8452      Consumer Defensive             57270
# 2   100-0004         Basic Materials             23218
# 3   103-8210      Consumer Defensive             33603
# 4   103-8668              Healthcare             47495
# 5   103-8411              Healthcare             15883
# 6   100-8071         Basic Materials            106599
# 7   107-8414             Industrials             62823
# 8   100-8280             Industrials            301056
# 9   105-8001             Industrials            125648
# 10  571-8501              Technology            246512
# 11  108-0075              Technology            111700
# 12  401-0597             Industrials              8164
# 13  220-8686       Consumer Cyclical            136134
# 14  471-8571       Consumer Cyclical            359542
# 15  107-8556       Consumer Cyclical             36313
# 16  146-8501              Technology            187041
# 17  100-8631                  Energy             45624
# 18  100-8086             Industrials               NaN
# 19  100-8330      Financial Services            133200
# 20  100-0005      Financial Services             86400
# 21  100-8176      Financial Services             56383
# 22  103-8645      Financial Services             26629
# 23  100-0005      Financial Services             41101
# 24  100-8133             Real Estate              9619
# 25  530-8341             Industrials             48323
# 26  100-8116  Communication Services            319039
# 27  102-8460  Communication Services             44952
# 28  100-6150  Communication Services             27558
# 29  105-7317  Communication Services             80909
#
#                                   longBusinessSummary       city  \
# 0   Japan Tobacco Inc., a tobacco company, manufac...      Tokyo
# 1   Seven & i Holdings Co., Ltd. engages in retail...      Tokyo
# 2   Shin-Etsu Chemical Co., Ltd. manufactures and ...      Tokyo
# 3   Kao Corporation develops and sells cosmetic, s...      Tokyo
# 4   Takeda Pharmaceutical Company Limited engages ...      Tokyo
# 5   Astellas Pharma Inc. manufactures, markets, an...      Tokyo
# 6   Nippon Steel Corporation, together with its su...      Tokyo
# 7   Komatsu Ltd. manufactures and sells constructi...      Tokyo
# 8   Hitachi, Ltd. provides information technology,...      Tokyo
# 9   Toshiba Corporation, together with its subsidi...      Tokyo
# 10  Panasonic Corporation, together with its subsi...     Kadoma
# 11  Sony Corporation designs, develops, produces, ...      Tokyo
# 12  Fanuc Corporation provides factory automation ...  Yamanashi
# 13  Nissan Motor Co., Ltd. manufactures and sells ...   Yokohama
# 14  Toyota Motor Corporation designs, manufactures...     Toyota
# 15  Honda Motor Co., Ltd. develops, manufactures, ...      Tokyo
# 16  Canon Inc. manufactures and sells office multi...      Tokyo
# 17  Mitsui & Co., Ltd. operates as a general tradi...      Tokyo
# 18  Mitsubishi Corporation engages in the natural ...      Tokyo
# 19  Mitsubishi UFJ Financial Group, Inc., a bank h...      Tokyo
# 20  Sumitomo Mitsui Financial Group, Inc., togethe...      Tokyo
# 21  Mizuho Financial Group, Inc., together with it...      Tokyo
# 22  Nomura Holdings, Inc. provides various financi...      Tokyo
# 23  Tokio Marine Holdings, Inc. engages in non-lif...      Tokyo
# 24  Mitsubishi Estate Co., Ltd. engages in the rea...      Tokyo
# 25  West Japan Railway Company provides passenger ...      Osaka
# 26  Nippon Telegraph and Telephone Corporation, th...      Tokyo
# 27  KDDI Corporation provides telecommunications s...      Tokyo
# 28  NTT DOCOMO, INC., a telecommunications company...      Tokyo
# 29  SoftBank Group Corp. provides telecommunicatio...      Tokyo
#
#              phone country companyOfficers  \
# 0   81 3 3582 3111   Japan             NaN
# 1   81 3 6238 3000   Japan             NaN
# 2   81 3 3246 5091   Japan             NaN
# 3   81 3 3660 7111   Japan             NaN
# 4   81 3 3278 2306   Japan             NaN
# 5   81 3 3244 3000   Japan             NaN
# 6   81 3 6867 4111   Japan             NaN
# 7   81 3 5561 4711   Japan             NaN
# 8   81 3 3258 1111   Japan             NaN
# 9   81 3 3457 4511   Japan             NaN
# 10  81 6 6908 1121   Japan             NaN
# 11  81 3 6748 2111   Japan             NaN
# 12  81 555 84 5555   Japan             NaN
# 13  81 45 523 5523   Japan             NaN
# 14  81 565 28 2121   Japan             NaN
# 15  81 3 3423 1111   Japan             NaN
# 16  81 3 3758 2111   Japan             NaN
# 17  81 3 3285 1111   Japan             NaN
# 18  81 3 3210 2121   Japan             NaN
# 19  81 3 3240 8111   Japan             NaN
# 20  81 3 3282 8111   Japan             NaN
# 21  81 3 5224 1111   Japan             NaN
# 22  81 3 5255 1000   Japan             NaN
# 23             NaN   Japan             NaN
# 24  81 3 3287 5100   Japan             NaN
# 25  81 6 6375 8708   Japan             NaN
# 26  81 3 6838 5111   Japan             NaN
# 27  81 3 3347 0077   Japan             NaN
# 28  81 3 5156 1111   Japan             NaN
# 29  81 3 6889 2000   Japan             NaN
#
#                                       website maxAge  ... dateShortInterest  \
# 0                           http://www.jt.com      1  ...               NaN
# 1                        http://www.7andi.com      1  ...               NaN
# 2                   http://www.shinetsu.co.jp      1  ...               NaN
# 3                      http://www.kao.com/jp/      1  ...               NaN
# 4                       http://www.takeda.com      1  ...               NaN
# 5                     http://www.astellas.com      1  ...               NaN
# 6                  http://www.nipponsteel.com      1  ...               NaN
# 7                     http://home.komatsu/en/      1  ...               NaN
# 8                   http://www.hitachi.co.jp/      1  ...               NaN
# 9                    http://www.toshiba.co.jp      1  ...               NaN
# 10  http://www.panasonic.com/global/home.html      1  ...               NaN
# 11                        http://www.sony.net      1  ...               NaN
# 12                     http://www.fanuc.co.jp      1  ...               NaN
# 13               http://www.nissan-global.com      1  ...               NaN
# 14                    http://global.toyota/en      1  ...               NaN
# 15                     http://www.honda.co.jp      1  ...               NaN
# 16                        http://global.canon      1  ...               NaN
# 17                http://www.mitsui.com/jp/en      1  ...               NaN
# 18              http://www.mitsubishicorp.com      1  ...               NaN
# 19                         http://www.mufg.jp      1  ...               NaN
# 20                      http://www.smfg.co.jp      1  ...               NaN
# 21                 http://www.mizuho-fg.co.jp      1  ...               NaN
# 22                      http://www.nomura.com      1  ...               NaN
# 23               http://www.tokiomarinehd.com      1  ...               NaN
# 24                       http://www.mec.co.jp      1  ...               NaN
# 25                    http://www.westjr.co.jp      1  ...               NaN
# 26                       http://www.ntt.co.jp      1  ...               NaN
# 27                        http://www.kddi.com      1  ...               NaN
# 28                 http://www.nttdocomo.co.jp      1  ...               NaN
# 29                      http://group.softbank      1  ...               NaN
#
#    pegRatio lastCapGain shortPercentOfFloat sharesShortPriorMonth category  \
# 0       NaN         NaN                 NaN                   NaN      NaN
# 1       NaN         NaN                 NaN                   NaN      NaN
# 2       NaN         NaN                 NaN                   NaN      NaN
# 3       NaN         NaN                 NaN                   NaN      NaN
# 4       NaN         NaN                 NaN                   NaN      NaN
# 5       NaN         NaN                 NaN                   NaN      NaN
# 6       NaN         NaN                 NaN                   NaN      NaN
# 7       NaN         NaN                 NaN                   NaN      NaN
# 8       NaN         NaN                 NaN                   NaN      NaN
# 9       NaN         NaN                 NaN                   NaN      NaN
# 10      NaN         NaN                 NaN                   NaN      NaN
# 11      NaN         NaN                 NaN                   NaN      NaN
# 12      NaN         NaN                 NaN                   NaN      NaN
# 13      NaN         NaN                 NaN                   NaN      NaN
# 14      NaN         NaN                 NaN                   NaN      NaN
# 15      NaN         NaN                 NaN                   NaN      NaN
# 16      NaN         NaN                 NaN                   NaN      NaN
# 17      NaN         NaN                 NaN                   NaN      NaN
# 18      NaN         NaN                 NaN                   NaN      NaN
# 19      NaN         NaN                 NaN                   NaN      NaN
# 20      NaN         NaN                 NaN                   NaN      NaN
# 21      NaN         NaN                 NaN                   NaN      NaN
# 22      NaN         NaN                 NaN                   NaN      NaN
# 23      NaN         NaN                 NaN                   NaN      NaN
# 24      NaN         NaN                 NaN                   NaN      NaN
# 25      NaN         NaN                 NaN                   NaN      NaN
# 26      NaN         NaN                 NaN                   NaN      NaN
# 27      NaN         NaN                 NaN                   NaN      NaN
# 28      NaN         NaN                 NaN                   NaN      NaN
# 29      NaN         NaN                 NaN                   NaN      NaN
#
#    fiveYearAverageReturn regularMarketPrice  \
# 0                    NaN             2177.5
# 1                    NaN               3491
# 2                    NaN              16795
# 3                    NaN               7948
# 4                    NaN               3689
# 5                    NaN               1580
# 6                    NaN               1323
# 7                    NaN               2574
# 8                    NaN               4031
# 9                    NaN               2809
# 10                   NaN             1125.5
# 11                   NaN               9794
# 12                   NaN              25720
# 13                   NaN              527.3
# 14                   NaN               7300
# 15                   NaN               2982
# 16                   NaN               1945
# 17                   NaN               1865
# 18                   NaN               2498
# 19                   NaN              468.6
# 20                   NaN               3167
# 21                   NaN               1377
# 22                   NaN              534.3
# 23                   NaN               5454
# 24                   NaN             1861.5
# 25                   NaN               5114
# 26                   NaN               2506
# 27                   NaN               3064
# 28                   NaN               3872
# 29                   NaN               7155
#
#                                         logo_url  ticker
# 0               https://logo.clearbit.com/jt.com  2914.T
# 1            https://logo.clearbit.com/7andi.com  3382.T
# 2       https://logo.clearbit.com/shinetsu.co.jp  4063.T
# 3              https://logo.clearbit.com/kao.com  4452.T
# 4           https://logo.clearbit.com/takeda.com  4502.T
# 5         https://logo.clearbit.com/astellas.com  4503.T
# 6      https://logo.clearbit.com/nipponsteel.com  5401.T
# 7         https://logo.clearbit.com/home.komatsu  6301.T
# 8        https://logo.clearbit.com/hitachi.co.jp  6501.T
# 9        https://logo.clearbit.com/toshiba.co.jp  6502.T
# 10       https://logo.clearbit.com/panasonic.com  6752.T
# 11            https://logo.clearbit.com/sony.net  6758.T
# 12         https://logo.clearbit.com/fanuc.co.jp  6954.T
# 13   https://logo.clearbit.com/nissan-global.com  7201.T
# 14       https://logo.clearbit.com/global.toyota  7203.T
# 15         https://logo.clearbit.com/honda.co.jp  7267.T
# 16        https://logo.clearbit.com/global.canon  7751.T
# 17          https://logo.clearbit.com/mitsui.com  8031.T
# 18  https://logo.clearbit.com/mitsubishicorp.com  8058.T
# 19             https://logo.clearbit.com/mufg.jp  8306.T
# 20          https://logo.clearbit.com/smfg.co.jp  8316.T
# 21     https://logo.clearbit.com/mizuho-fg.co.jp  8411.T
# 22          https://logo.clearbit.com/nomura.com  8604.T
# 23   https://logo.clearbit.com/tokiomarinehd.com  8766.T
# 24           https://logo.clearbit.com/mec.co.jp  8802.T
# 25        https://logo.clearbit.com/westjr.co.jp  9021.T
# 26           https://logo.clearbit.com/ntt.co.jp  9432.T
# 27            https://logo.clearbit.com/kddi.com  9433.T
# 28     https://logo.clearbit.com/nttdocomo.co.jp  9437.T
# 29      https://logo.clearbit.com/group.softbank  9984.T
#
# [30 rows x 126 columns]

# %%
# トヨタ自動車
ticker = yf.Ticker("7203.T")

# %%
# トヨタ自動車
ticker = yf.Ticker("7203.T")

# %%
# 銘柄サマリ
info = ticker.info
pprint(info)
# Out:
# {'52WeekChange': -0.062806904,
#  'SandP52WeekChange': 0.16843343,
#  'address1': '1 Toyota-cho',
#  'algorithm': None,
#  'annualHoldingsTurnover': None,
#  'annualReportExpenseRatio': None,
#  'ask': 7263,
#  'askSize': 0,
#  'averageDailyVolume10Day': 5621957,
#  'averageVolume': 4653604,
#  'averageVolume10days': 5621957,
#  'beta': 0.779987,
#  'beta3Year': None,
#  'bid': 7251,
#  'bidSize': 0,
#  'bookValue': 7514.668,
#  'category': None,
#  'circulatingSupply': None,
#  'city': 'Toyota',
#  'companyOfficers': [],
#  'country': 'Japan',
#  'currency': 'JPY',
#  'dateShortInterest': None,
#  'dayHigh': 7327,
#  'dayLow': 7188,
#  'dividendRate': 220,
#  'dividendYield': 0.0299,
#  'earningsQuarterlyGrowth': -0.205,
#  'enterpriseToEbitda': 11.337,
#  'enterpriseToRevenue': 1.386,
#  'enterpriseValue': 36075657494528,
#  'exDividendDate': 1601337600,
#  'exchange': 'JPX',
#  'exchangeTimezoneName': 'Asia/Tokyo',
#  'exchangeTimezoneShortName': 'JST',
#  'expireDate': None,
#  'fiftyDayAverage': 7110.5884,
#  'fiftyTwoWeekHigh': 8026,
#  'fiftyTwoWeekLow': 5771,
#  'fiveYearAverageReturn': None,
#  'fiveYearAvgDividendYield': 3.25,
#  'floatShares': 2129778798,
#  'forwardEps': 836.47,
#  'forwardPE': 8.669767,
#  'fromCurrency': None,
#  'fullTimeEmployees': 359542,
#  'fundFamily': None,
#  'fundInceptionDate': None,
#  'gmtOffSetMilliseconds': '32400000',
#  'heldPercentInsiders': 0.23608999,
#  'heldPercentInstitutions': 0.22534001,
#  'industry': 'Auto Manufacturers',
#  'isEsgPopulated': False,
#  'lastCapGain': None,
#  'lastDividendDate': 1585526400,
#  'lastDividendValue': 120,
#  'lastFiscalYearEnd': 1585612800,
#  'lastMarket': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'logo_url': 'https://logo.clearbit.com/global.toyota',
#  'longBusinessSummary': 'Toyota Motor Corporation designs, manufactures, '
#                         'assembles, and sells passenger vehicles, minivans and '
#                         'commercial vehicles, and related parts and '
#                         'accessories. It operates in Automotive, Financial '
#                         'Services, and All Other segments. The company offers '
#                         'hybrid cars under the Prius, Prius PHV, C-HR, LC HV, '
#                         'LS HV, Camry, JPN TAXI, Avalon, Crown, Century HV, UX '
#                         'HV, Corolla SD, Corolla Sport, and WG HV names; fuel '
#                         'cell vehicles under the MIRAI and SORA names; and '
#                         'conventional engine vehicles, including subcompact '
#                         'and compact cars under the Yaris, Aqua, Passo, Roomy, '
#                         'Tank, Etios, Vios, AGYA, Rush, GLANZA, and Raize '
#                         'names. It also provides mini-vehicles, passenger '
#                         'vehicles, commercial vehicles, and auto parts under '
#                         'the Toyota name; mid-size cars under the Camry and '
#                         'REIZ names; luxury cars under the Lexus, Avalon, and '
#                         'Crown names; Century limousines; sports cars under '
#                         'the LC and Supra names; and recreational and '
#                         'sport-utility vehicles under the Sequoia, 4Runner, '
#                         'RAV4, Highlander, and Land Cruiser names. In '
#                         'addition, the company offers pickup trucks under the '
#                         'Tacoma and Tundra names; Minivans, Cabwagons, and '
#                         'Semi-Bonnet Wagon under the Alphard, Vellfire, '
#                         'Noah/Voxy, Esquire, Calya, Estima, Sienta, and Sienna '
#                         'names; and trucks and buses. Further, it provides '
#                         'financial services, such as retail financing and '
#                         'leasing, wholesale financing, insurance, and credit '
#                         'cards; and designs, manufactures, and sells '
#                         'prefabricated housing. Additionally, the company '
#                         'operates GAZOO.com, a web portal for automobile '
#                         'information. It operates in Japan, North America, '
#                         'Europe, Asia, Central and South America, Oceania, '
#                         'Africa, and the Middle East. The company was founded '
#                         'in 1933 and is headquartered in Toyota, Japan.',
#  'longName': 'Toyota Motor Corporation',
#  'market': 'jp_market',
#  'marketCap': 20276301529088,
#  'maxAge': 1,
#  'maxSupply': None,
#  'messageBoardId': 'finmb_319676',
#  'morningStarOverallRating': None,
#  'morningStarRiskRating': None,
#  'mostRecentQuarter': 1601424000,
#  'navPrice': None,
#  'netIncomeToCommon': 1421933019136,
#  'nextFiscalYearEnd': 1648684800,
#  'open': 7300,
#  'openInterest': None,
#  'payoutRatio': 0.4001,
#  'pegRatio': None,
#  'phone': '81 565 28 2121',
#  'previousClose': 7301,
#  'priceHint': 2,
#  'priceToBook': 0.965046,
#  'priceToSalesTrailing12Months': 0.7792697,
#  'profitMargins': 0.054980002,
#  'quoteType': 'EQUITY',
#  'regularMarketDayHigh': 7327,
#  'regularMarketDayLow': 7188,
#  'regularMarketOpen': 7300,
#  'regularMarketPreviousClose': 7301,
#  'regularMarketPrice': 7300,
#  'regularMarketVolume': 7455800,
#  'revenueQuarterlyGrowth': None,
#  'sector': 'Consumer Cyclical',
#  'sharesOutstanding': 2795960064,
#  'sharesPercentSharesOut': None,
#  'sharesShort': None,
#  'sharesShortPreviousMonthDate': None,
#  'sharesShortPriorMonth': None,
#  'shortName': 'TOYOTA MOTOR CORP',
#  'shortPercentOfFloat': None,
#  'shortRatio': None,
#  'startDate': None,
#  'strikePrice': None,
#  'symbol': '7203.T',
#  'threeYearAverageReturn': None,
#  'toCurrency': None,
#  'totalAssets': None,
#  'tradeable': False,
#  'trailingAnnualDividendRate': 120,
#  'trailingAnnualDividendYield': 0.016436104,
#  'trailingEps': 507.402,
#  'trailingPE': 14.292415,
#  'twoHundredDayAverage': 6912.0425,
#  'volume': 7455800,
#  'volume24Hr': None,
#  'volumeAllCurrencies': None,
#  'website': 'http://global.toyota/en',
#  'yield': None,
#  'ytdReturn': None,
#  'zip': '471-8571'}
